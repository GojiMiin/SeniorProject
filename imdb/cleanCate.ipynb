# %%
import pandas as pd

# %%
allData = pd.read_csv('18_19.csv')
allData
# Out:
#           code  year                                         name     time  \
# 0    tt4154756  2018                       Avengers: Infinity War  149 min
# 1    tt1477834  2018                                      Aquaman  143 min
# 2    tt3778644  2018                      Solo: A Star Wars Story  135 min
# 3    tt4123430  2018  Fantastic Beasts: The Crimes of Grindelwald  134 min
# 4    tt1825683  2018                                Black Panther  134 min
# ..         ...   ...                                          ...      ...
# 195  tt6394270  2019                                    Bombshell  109 min
# 196  tt4648786  2019                                      Harriet  125 min
# 197  tt9243946  2019              El Camino: A Breaking Bad Movie  122 min
# 198  tt9071322  2019                                  Dark Waters  126 min
# 199  tt7439064  2019                              The Rising Hawk  104 min
#
#                        category   rate  imdbscore  \
# ...

# %%
singleCate = []
allCate = allData["category"]
allCate
# Out:
# 0       Action, Adventure, Sci-Fi
# 1      Action, Adventure, Fantasy
# 2       Action, Adventure, Sci-Fi
# 3      Adventure, Family, Fantasy
# 4       Action, Adventure, Sci-Fi
#                   ...
# 195              Biography, Drama
# 196      Action, Biography, Drama
# 197          Action, Crime, Drama
# 198     Biography, Drama, History
# 199        Action, Drama, History
# Name: category, Length: 200, dtype: object

# %%
print(allCate[0].split(','))
# Out:
# ['Action', ' Adventure', ' Sci-Fi']

# %%
for i in allCate:
    row = i.split(',')
    for j in row:
        cleanSpace = j.replace(" ", "")
        if cleanSpace not in singleCate:
            singleCate.append(cleanSpace)

# %%
singleCate.sort()
singleCate
# Out:
# ['Action',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'Romance',
#  'Sci-Fi',
#  'Sport',
#  'Thriller',
#  'War',
#  'Western']
